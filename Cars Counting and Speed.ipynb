# %%
import cv2
from ultralytics import YOLO
import time

# load model
model = YOLO("yolov8m.pt")

# get names from classes
Classes = model.model.names

# defined Target Classes
lst = ["car", "bus", "truck"]
TargetClasses = {key: Classes[key] for key in Classes if Classes[key] in lst}
ClsInx = list(TargetClasses.keys())

# defind 2 lines to calculate speed
line1_y = 250  # first line
line2_y = 400  # second line
speed_limit = 60  # speed limit

# load video
cap = cv2.VideoCapture(r"D:\dask\cars.mp4")

# store dataset vechicles
TotalCounter = set()
car_dict = {}

while True :
    ret, frame = cap.read()
    if not ret:
        print("video end")
        break

    # draw lines
    cv2.line(frame, (0, line1_y), (frame.shape[1], line1_y), (255, 0, 0), 2)  ## draw first line
    cv2.line(frame, (0, line2_y), (frame.shape[1], line2_y), (0, 0, 255), 2)  ## draw second line

    # operate yolo on frame to track object
    results = model.track(frame, persist=True, classes=ClsInx, show=False, conf=0.1)

    for result in results:
        boxes = result.boxes.xyxy
        ids = result.boxes.id
        classes = result.boxes.cls

        for box, id, cls in zip(boxes, ids, classes):
            x, y, w, h = map(int, box)
            cx, cy = (x + w) // 2, (y + h) // 2  # center of car

            if int(cls) in ClsInx:
                # add car if not added before
                if int(id) not in car_dict:
                    car_dict[int(id)] = {'entered': False, 'passed': False, 'time': None, 'speed': None}

                # record pass time for first one for car
                if cy >= line1_y and not car_dict[int(id)]['entered']:
                    car_dict[int(id)]['time'] = time.time()
                    car_dict[int(id)]['entered'] = True  # passed first one
                
                # calc speed after pass second line after passing first line
                if car_dict[int(id)]['entered'] and not car_dict[int(id)]['passed'] and cy >= line2_y:
                    elapsed_time = time.time() - car_dict[int(id)]['time']  ## calc time between 2 lines
                    speed = 150 / elapsed_time  # speed by pexel
                    car_dict[int(id)]['speed'] = speed
                    car_dict[int(id)]['passed'] = True  # record that car passed

                    ## add car to counter for recording it
                    TotalCounter.add(int(id))

                # draw rectangle around car
                cv2.rectangle(frame, (x, y), (w, h), (0, 255, 0), 2)

                # display ID for car
                cv2.putText(frame, 
                            f"ID: {int(id)}", 
                            (x, y - 10), 
                            cv2.FONT_HERSHEY_SIMPLEX, 
                            0.6, 
                            (0, 255, 255), 
                            2)

                # display speed for px/s
                if car_dict[int(id)]['speed'] is not None:
                    speed_text = f"Speed: {int(car_dict[int(id)]['speed'])} px/s"
                    color = (0, 255, 0) if car_dict[int(id)]['speed'] <= speed_limit else (0, 0, 255)  # red if car is heiest than speed limit
                    cv2.putText(frame, speed_text, (x, y - 35), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

                    # Warning if Speed higher than speed limit
                    if car_dict[int(id)]['speed'] > speed_limit:
                        cv2.putText(frame, "OVERSPEED!", (x, y - 60), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    # display the Total Vechicles if passed 2 lines only
    cv2.putText(frame, f"Total Vehicles: {len(TotalCounter)}", (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 3)

    # display frame 
    cv2.imshow("Vehicle Speed Tracking", frame)

    
    if cv2.waitKey(50) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 6 cars, 210.0ms
# Speed: 7.0ms preprocess, 210.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 232.0ms
# Speed: 2.0ms preprocess, 232.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 221.0ms
# Speed: 1.0ms preprocess, 221.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 220.0ms
# Speed: 2.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 215.0ms
# Speed: 2.0ms preprocess, 215.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 212.0ms
# Speed: 2.0ms preprocess, 212.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 208.0ms
# Speed: 2.0ms preprocess, 208.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 213.0ms
# Speed: 2.0ms preprocess, 213.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 208.0ms
# Speed: 2.0ms preprocess, 208.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 223.3ms
# Speed: 2.0ms preprocess, 223.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 209.0ms
# Speed: 2.0ms preprocess, 209.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 211.0ms
# Speed: 2.0ms preprocess, 211.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 212.0ms
# Speed: 2.0ms preprocess, 212.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 224.0ms
# Speed: 1.0ms preprocess, 224.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 210.6ms
# Speed: 2.0ms preprocess, 210.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 215.0ms
# Speed: 1.0ms preprocess, 215.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 216.0ms
# Speed: 1.0ms preprocess, 216.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 223.0ms
# Speed: 3.0ms preprocess, 223.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 217.0ms
# Speed: 1.0ms preprocess, 217.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 211.0ms
# Speed: 2.0ms preprocess, 211.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 224.0ms
# Speed: 1.0ms preprocess, 224.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 211.0ms
# Speed: 2.0ms preprocess, 211.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 213.0ms
# Speed: 2.0ms preprocess, 213.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 213.0ms
# Speed: 2.0ms preprocess, 213.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 217.0ms
# Speed: 2.0ms preprocess, 217.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 219.0ms
# Speed: 3.0ms preprocess, 219.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 220.0ms
# Speed: 2.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 214.0ms
# Speed: 2.0ms preprocess, 214.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 224.0ms
# Speed: 2.0ms preprocess, 224.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 215.0ms
# Speed: 2.0ms preprocess, 215.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 221.0ms
# Speed: 2.0ms preprocess, 221.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 233.0ms
# Speed: 2.0ms preprocess, 233.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 248.0ms
# Speed: 3.0ms preprocess, 248.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 215.0ms
# Speed: 2.0ms preprocess, 215.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 211.0ms
# Speed: 2.0ms preprocess, 211.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 208.0ms
# Speed: 2.0ms preprocess, 208.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 223.0ms
# Speed: 2.0ms preprocess, 223.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 207.0ms
# Speed: 2.0ms preprocess, 207.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 213.0ms
# Speed: 2.0ms preprocess, 213.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 207.0ms
# Speed: 2.0ms preprocess, 207.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 219.5ms
# Speed: 2.0ms preprocess, 219.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 214.1ms
# Speed: 1.0ms preprocess, 214.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 207.0ms
# Speed: 2.0ms preprocess, 207.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 210.0ms
# Speed: 2.0ms preprocess, 210.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 219.0ms
# Speed: 2.0ms preprocess, 219.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 207.0ms
# Speed: 2.0ms preprocess, 207.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 207.0ms
# Speed: 2.0ms preprocess, 207.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 210.0ms
# Speed: 2.0ms preprocess, 210.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 222.0ms
# Speed: 2.0ms preprocess, 222.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 211.0ms
# Speed: 1.0ms preprocess, 211.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 210.0ms
# Speed: 2.0ms preprocess, 210.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 223.0ms
# Speed: 2.0ms preprocess, 223.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 224.0ms
# Speed: 2.0ms preprocess, 224.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 209.0ms
# Speed: 2.0ms preprocess, 209.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 213.0ms
# Speed: 2.0ms preprocess, 213.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 220.6ms
# Speed: 2.0ms preprocess, 220.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 213.0ms
# Speed: 2.0ms preprocess, 213.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 222.0ms
# Speed: 1.0ms preprocess, 222.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 216.0ms
# Speed: 2.0ms preprocess, 216.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 223.0ms
# Speed: 3.0ms preprocess, 223.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 218.0ms
# Speed: 1.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 224.0ms
# Speed: 1.0ms preprocess, 224.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 212.0ms
# Speed: 2.0ms preprocess, 212.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 211.0ms
# Speed: 2.0ms preprocess, 211.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 232.0ms
# Speed: 2.0ms preprocess, 232.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 239.0ms
# Speed: 2.0ms preprocess, 239.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 217.0ms
# Speed: 2.0ms preprocess, 217.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 217.0ms
# Speed: 2.0ms preprocess, 217.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 217.0ms
# Speed: 2.0ms preprocess, 217.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 290.0ms
# Speed: 2.0ms preprocess, 290.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 224.0ms
# Speed: 2.0ms preprocess, 224.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 229.0ms
# Speed: 2.0ms preprocess, 229.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 223.0ms
# Speed: 2.0ms preprocess, 223.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 233.0ms
# Speed: 2.0ms preprocess, 233.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 222.0ms
# Speed: 2.0ms preprocess, 222.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 215.0ms
# Speed: 2.0ms preprocess, 215.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 226.0ms
# Speed: 2.0ms preprocess, 226.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 231.0ms
# Speed: 3.0ms preprocess, 231.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 222.0ms
# Speed: 2.0ms preprocess, 222.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 220.0ms
# Speed: 2.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 233.0ms
# Speed: 2.0ms preprocess, 233.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 225.0ms
# Speed: 1.0ms preprocess, 225.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 232.0ms
# Speed: 2.0ms preprocess, 232.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 224.0ms
# Speed: 2.0ms preprocess, 224.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 241.0ms
# Speed: 2.0ms preprocess, 241.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 230.0ms
# Speed: 2.0ms preprocess, 230.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 225.0ms
# Speed: 2.0ms preprocess, 225.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 219.0ms
# Speed: 2.0ms preprocess, 219.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 229.0ms
# Speed: 2.0ms preprocess, 229.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 223.0ms
# Speed: 2.0ms preprocess, 223.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 224.0ms
# Speed: 2.0ms preprocess, 224.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 234.0ms
# Speed: 2.0ms preprocess, 234.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 226.4ms
# Speed: 2.0ms preprocess, 226.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 220.0ms
# Speed: 3.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 236.0ms
# Speed: 2.0ms preprocess, 236.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 222.0ms
# Speed: 2.0ms preprocess, 222.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 241.0ms
# Speed: 2.0ms preprocess, 241.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 235.0ms
# Speed: 2.0ms preprocess, 235.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 215.0ms
# Speed: 2.0ms preprocess, 215.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 216.0ms
# Speed: 2.0ms preprocess, 216.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 225.0ms
# Speed: 2.0ms preprocess, 225.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 209.0ms
# Speed: 2.0ms preprocess, 209.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 208.0ms
# Speed: 2.0ms preprocess, 208.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 226.0ms
# Speed: 2.0ms preprocess, 226.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 214.0ms
# Speed: 2.0ms preprocess, 214.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 212.0ms
# Speed: 2.0ms preprocess, 212.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 214.0ms
# Speed: 2.0ms preprocess, 214.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 232.0ms
# Speed: 2.0ms preprocess, 232.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 211.0ms
# Speed: 2.0ms preprocess, 211.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 217.5ms
# Speed: 2.0ms preprocess, 217.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 214.0ms
# Speed: 2.0ms preprocess, 214.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 228.0ms
# Speed: 2.0ms preprocess, 228.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 217.0ms
# Speed: 3.0ms preprocess, 217.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 217.0ms
# Speed: 1.0ms preprocess, 217.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 222.0ms
# Speed: 2.0ms preprocess, 222.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 217.0ms
# Speed: 3.0ms preprocess, 217.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 212.0ms
# Speed: 1.0ms preprocess, 212.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 220.0ms
# Speed: 2.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 229.0ms
# Speed: 2.0ms preprocess, 229.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 212.0ms
# Speed: 2.0ms preprocess, 212.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 219.0ms
# Speed: 1.0ms preprocess, 219.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 229.0ms
# Speed: 2.0ms preprocess, 229.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 226.0ms
# Speed: 2.0ms preprocess, 226.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 225.0ms
# Speed: 1.0ms preprocess, 225.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 219.0ms
# Speed: 2.0ms preprocess, 219.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 220.0ms
# Speed: 2.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 220.6ms
# Speed: 2.0ms preprocess, 220.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 232.0ms
# Speed: 2.0ms preprocess, 232.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 239.0ms
# Speed: 1.0ms preprocess, 239.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 222.0ms
# Speed: 2.0ms preprocess, 222.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 216.5ms
# Speed: 2.0ms preprocess, 216.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 215.0ms
# Speed: 2.0ms preprocess, 215.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 231.0ms
# Speed: 2.0ms preprocess, 231.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 220.0ms
# Speed: 2.0ms preprocess, 220.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 220.0ms
# Speed: 2.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 238.0ms
# Speed: 8.0ms preprocess, 238.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 215.0ms
# Speed: 1.0ms preprocess, 215.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 221.0ms
# Speed: 2.0ms preprocess, 221.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 216.0ms
# Speed: 2.0ms preprocess, 216.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 218.0ms
# Speed: 1.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 229.0ms
# Speed: 2.0ms preprocess, 229.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 211.0ms
# Speed: 2.0ms preprocess, 211.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 212.0ms
# Speed: 2.0ms preprocess, 212.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 218.0ms
# Speed: 1.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 232.0ms
# Speed: 2.0ms preprocess, 232.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 213.0ms
# Speed: 2.0ms preprocess, 213.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 217.0ms
# Speed: 2.0ms preprocess, 217.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 225.0ms
# Speed: 2.0ms preprocess, 225.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 218.0ms
# Speed: 1.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 221.0ms
# Speed: 2.0ms preprocess, 221.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 219.0ms
# Speed: 2.0ms preprocess, 219.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 216.0ms
# Speed: 1.0ms preprocess, 216.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 212.0ms
# Speed: 2.0ms preprocess, 212.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 274.0ms
# Speed: 1.0ms preprocess, 274.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 217.0ms
# Speed: 2.0ms preprocess, 217.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 214.0ms
# Speed: 2.0ms preprocess, 214.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 234.0ms
# Speed: 1.0ms preprocess, 234.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 253.0ms
# Speed: 2.0ms preprocess, 253.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 215.0ms
# Speed: 2.0ms preprocess, 215.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 216.0ms
# Speed: 2.0ms preprocess, 216.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 220.0ms
# Speed: 1.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 230.0ms
# Speed: 2.0ms preprocess, 230.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 216.0ms
# Speed: 2.0ms preprocess, 216.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 215.0ms
# Speed: 1.0ms preprocess, 215.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 216.0ms
# Speed: 1.0ms preprocess, 216.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 226.0ms
# Speed: 2.0ms preprocess, 226.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 219.5ms
# Speed: 1.0ms preprocess, 219.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 215.0ms
# Speed: 2.0ms preprocess, 215.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 214.0ms
# Speed: 2.0ms preprocess, 214.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 225.0ms
# Speed: 2.0ms preprocess, 225.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 250.0ms
# Speed: 1.0ms preprocess, 250.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 214.0ms
# Speed: 2.0ms preprocess, 214.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 227.0ms
# Speed: 2.0ms preprocess, 227.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 226.0ms
# Speed: 2.0ms preprocess, 226.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 223.0ms
# Speed: 2.0ms preprocess, 223.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 223.8ms
# Speed: 2.0ms preprocess, 223.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 229.3ms
# Speed: 2.0ms preprocess, 229.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 214.0ms
# Speed: 1.0ms preprocess, 214.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 226.6ms
# Speed: 2.0ms preprocess, 226.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 219.0ms
# Speed: 3.0ms preprocess, 219.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 222.0ms
# Speed: 2.0ms preprocess, 222.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 217.0ms
# Speed: 2.0ms preprocess, 217.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 216.0ms
# Speed: 2.0ms preprocess, 216.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 231.5ms
# Speed: 1.0ms preprocess, 231.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 222.0ms
# Speed: 2.0ms preprocess, 222.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 212.0ms
# Speed: 2.0ms preprocess, 212.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 220.0ms
# Speed: 2.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 245.0ms
# Speed: 2.0ms preprocess, 245.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 223.5ms
# Speed: 2.0ms preprocess, 223.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 229.0ms
# Speed: 2.0ms preprocess, 229.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 220.0ms
# Speed: 2.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 223.0ms
# Speed: 2.0ms preprocess, 223.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 215.0ms
# Speed: 2.0ms preprocess, 215.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 218.0ms
# Speed: 1.0ms preprocess, 218.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 220.0ms
# Speed: 2.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 216.0ms
# Speed: 2.0ms preprocess, 216.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 220.0ms
# Speed: 2.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 215.0ms
# Speed: 1.0ms preprocess, 215.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 225.0ms
# Speed: 2.0ms preprocess, 225.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 211.0ms
# Speed: 2.0ms preprocess, 211.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 215.0ms
# Speed: 1.0ms preprocess, 215.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 214.0ms
# Speed: 2.0ms preprocess, 214.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 223.0ms
# Speed: 1.0ms preprocess, 223.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 216.0ms
# Speed: 1.0ms preprocess, 216.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 222.0ms
# Speed: 2.0ms preprocess, 222.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 223.0ms
# Speed: 3.0ms preprocess, 223.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 220.0ms
# Speed: 2.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 215.0ms
# Speed: 2.0ms preprocess, 215.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 223.0ms
# Speed: 2.0ms preprocess, 223.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 215.9ms
# Speed: 2.0ms preprocess, 215.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 216.0ms
# Speed: 1.0ms preprocess, 216.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 217.0ms
# Speed: 1.0ms preprocess, 217.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 222.0ms
# Speed: 2.0ms preprocess, 222.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 220.0ms
# Speed: 2.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 219.2ms
# Speed: 2.0ms preprocess, 219.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 218.0ms
# Speed: 1.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 219.0ms
# Speed: 2.0ms preprocess, 219.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 219.0ms
# Speed: 2.0ms preprocess, 219.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 224.0ms
# Speed: 2.0ms preprocess, 224.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 241.0ms
# Speed: 2.0ms preprocess, 241.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 231.0ms
# Speed: 1.0ms preprocess, 231.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 220.0ms
# Speed: 2.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 224.0ms
# Speed: 2.0ms preprocess, 224.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 216.0ms
# Speed: 2.0ms preprocess, 216.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 212.0ms
# Speed: 2.0ms preprocess, 212.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 224.0ms
# Speed: 2.0ms preprocess, 224.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 218.0ms
# Speed: 1.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 214.0ms
# Speed: 1.0ms preprocess, 214.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 217.0ms
# Speed: 1.0ms preprocess, 217.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 229.0ms
# Speed: 2.0ms preprocess, 229.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 219.5ms
# Speed: 2.0ms preprocess, 219.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 212.0ms
# Speed: 2.0ms preprocess, 212.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 219.5ms
# Speed: 2.0ms preprocess, 219.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 221.0ms
# Speed: 2.0ms preprocess, 221.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 219.0ms
# Speed: 3.0ms preprocess, 219.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 212.0ms
# Speed: 2.0ms preprocess, 212.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 229.0ms
# Speed: 2.0ms preprocess, 229.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 214.6ms
# Speed: 2.0ms preprocess, 214.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 216.0ms
# Speed: 2.0ms preprocess, 216.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 218.0ms
# Speed: 1.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 226.0ms
# Speed: 2.0ms preprocess, 226.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 214.0ms
# Speed: 2.0ms preprocess, 214.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 223.0ms
# Speed: 2.0ms preprocess, 223.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 206.0ms
# Speed: 2.0ms preprocess, 206.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 217.0ms
# Speed: 3.0ms preprocess, 217.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 228.0ms
# Speed: 1.0ms preprocess, 228.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 285.0ms
# Speed: 9.0ms preprocess, 285.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 224.0ms
# Speed: 2.0ms preprocess, 224.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 223.0ms
# Speed: 2.0ms preprocess, 223.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 247.0ms
# Speed: 3.0ms preprocess, 247.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 228.0ms
# Speed: 3.0ms preprocess, 228.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 241.0ms
# Speed: 2.0ms preprocess, 241.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 227.0ms
# Speed: 2.0ms preprocess, 227.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 230.0ms
# Speed: 2.0ms preprocess, 230.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 226.5ms
# Speed: 2.0ms preprocess, 226.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 222.0ms
# Speed: 2.0ms preprocess, 222.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 231.0ms
# Speed: 2.0ms preprocess, 231.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 221.0ms
# Speed: 2.0ms preprocess, 221.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 223.0ms
# Speed: 2.0ms preprocess, 223.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 269.0ms
# Speed: 2.0ms preprocess, 269.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 233.0ms
# Speed: 2.0ms preprocess, 233.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 222.0ms
# Speed: 2.0ms preprocess, 222.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 226.0ms
# Speed: 2.0ms preprocess, 226.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 234.0ms
# Speed: 1.0ms preprocess, 234.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 226.0ms
# Speed: 3.0ms preprocess, 226.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 223.0ms
# Speed: 2.0ms preprocess, 223.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 227.0ms
# Speed: 2.0ms preprocess, 227.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 236.0ms
# Speed: 2.0ms preprocess, 236.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 224.0ms
# Speed: 2.0ms preprocess, 224.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 227.0ms
# Speed: 2.0ms preprocess, 227.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 225.0ms
# Speed: 2.0ms preprocess, 225.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 233.0ms
# Speed: 4.0ms preprocess, 233.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 269.0ms
# Speed: 3.0ms preprocess, 269.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 219.5ms
# Speed: 2.0ms preprocess, 219.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 226.0ms
# Speed: 1.0ms preprocess, 226.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 222.0ms
# Speed: 2.0ms preprocess, 222.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 217.0ms
# Speed: 1.0ms preprocess, 217.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 214.0ms
# Speed: 2.0ms preprocess, 214.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 224.0ms
# Speed: 2.0ms preprocess, 224.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 218.0ms
# Speed: 2.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 212.1ms
# Speed: 1.0ms preprocess, 212.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 215.0ms
# Speed: 2.0ms preprocess, 215.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 225.0ms
# Speed: 2.0ms preprocess, 225.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 224.0ms
# Speed: 2.0ms preprocess, 224.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 235.0ms
# Speed: 2.0ms preprocess, 235.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 232.0ms
# Speed: 10.0ms preprocess, 232.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 216.0ms
# Speed: 2.0ms preprocess, 216.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 220.0ms
# Speed: 2.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 213.0ms
# Speed: 2.0ms preprocess, 213.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 233.0ms
# Speed: 2.0ms preprocess, 233.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 219.0ms
# Speed: 1.0ms preprocess, 219.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 213.0ms
# Speed: 2.0ms preprocess, 213.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 210.0ms
# Speed: 2.0ms preprocess, 210.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 228.5ms
# Speed: 2.0ms preprocess, 228.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 219.0ms
# Speed: 2.0ms preprocess, 219.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 218.0ms
# Speed: 1.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 221.0ms
# Speed: 2.0ms preprocess, 221.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 232.0ms
# Speed: 3.0ms preprocess, 232.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 220.0ms
# Speed: 1.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 226.0ms
# Speed: 2.0ms preprocess, 226.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 227.0ms
# Speed: 2.0ms preprocess, 227.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 214.0ms
# Speed: 2.0ms preprocess, 214.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 218.0ms
# Speed: 2.2ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 217.0ms
# Speed: 2.0ms preprocess, 217.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 229.1ms
# Speed: 2.0ms preprocess, 229.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 215.0ms
# Speed: 2.0ms preprocess, 215.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 216.0ms
# Speed: 2.0ms preprocess, 216.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 214.0ms
# Speed: 2.0ms preprocess, 214.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 227.0ms
# Speed: 3.0ms preprocess, 227.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 229.0ms
# Speed: 3.0ms preprocess, 229.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 217.0ms
# Speed: 2.0ms preprocess, 217.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 220.3ms
# Speed: 1.0ms preprocess, 220.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 220.0ms
# Speed: 2.0ms preprocess, 220.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 219.0ms
# Speed: 2.0ms preprocess, 219.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 213.0ms
# Speed: 2.0ms preprocess, 213.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video end
